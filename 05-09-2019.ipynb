# %% [markdown]
# ## markdown introduction

# %% [markdown]
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ##### heading5
# ###### heading6

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*<br/>
# <strike>Striking text</strike><br/>
# 'highlighting text'

# %% [markdown]
# <img src="http://icons.iconarchive.com/icons/cornmanthe3rd/plex/512/Other-python-icon.png" width="100px" height="100px">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%html
# <iframe width="853" height="480" src="https://www.youtube.com/embed/QXeEoD0pB3E?list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="853" height="480" src="https://www.youtube.com/embed/QXeEoD0pB3E?list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * Python
# * Java
# * R programming
# * Scripting languages
#  - html
#  - xml

# %% [markdown]
# # Python Programming

# %%
print("hello world!")
print("welcome to APSSDC")
# Out:
# hello world!
# welcome to APSSDC

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # Operators

# %% [markdown]
# * Arithmatic operators
# * Relational operators
# * Assignment operators
# * Bitwise operators
# * logical operators
# * Identity operators
# * Membership operators

# %% [markdown]
# ## Arithmatic Operators

# %%
print(100+20)
print(100-20)
print(5*3)
print(10/3)
# Out:
# 120
# 80
# 15
# 3.3333333333333335

# %%
type(1)
# Out:
# int

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %% [markdown]
# ## Logical operators

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ## Relational operators

# %%
2==3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2<10
# Out:
# True

# %%
10 > 20
# Out:
# False

# %% [markdown]
# ## assignment operators

# %%
a=10
b="saikumar"
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
a=b=c=10

# %%
print(a,b,c)
# Out:
# 10 10 10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
a,b,c=1,2,3

# %%
a,b,c
# Out:
# (1, 2, 3)

# %%
a,b=b,a

# %%
a,b
# Out:
# (2, 1)

# %%
a=1
a
# Out:
# 1

# %%
a++ #increment or decrement operators won't work in python
# Out:
#   File "<ipython-input-44-22e3d6dc1353>", line 1
#     a++
#        ^
# SyntaxError: invalid syntax

# %%
a=a+1
a
# Out:
# 3

# %%
a+=1
a
# Out:
# 5

# %%
a-=1
a
# Out:
# 4

# %%
a*=2
a
# Out:
# 8

# %%
a/=2
a
# Out:
# 0.5

# %% [markdown]
# ## Bitwise operators

# %%
4 & 7 # 4 - 1 0 0
      # 7 - 1 1 1
      # & - 1 0 0
# Out:
# 4

# %%
7 |4
# Out:
# 7

# %%
8<<2
# Out:
# 32

# %%
8>>2
# Out:
# 2

# %% [markdown]
# ## Identity operators

# %%
2 is 3 #2 == 3
# Out:
# False

# %%
2 is not 3 # 2!=3
# Out:
# True

# %% [markdown]
# ## Membership operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"AP" in "apssdc"
# Out:
# False

# %%
"T" not in "apssdc"
# Out:
# True
